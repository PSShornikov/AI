# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import keras
keras.__version__
# Out:
# '2.4.3'

# %%
from keras.datasets import mnist
from keras.utils import to_categorical

# %%
image_size = (32,32)
batch_size = 32
train_flow_path = '/Users/dmitry/Images/train' 
test_flow_path = '/Users/dmitry/Images/test'

# %%
data_gen_train = keras.preprocessing.image.ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
)

data_gen_test = keras.preprocessing.image.ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
)

train_images = data_gen_train.flow_from_directory(
    train_flow_path,
    target_size = image_size,
    batch_size = batch_size,
    color_mode = 'rgb',
    classes = ['A', 'B', 'D', 'E', 'G'],
    class_mode = 'categorical',
    shuffle = True,
    seed = 42
)

test_images = data_gen_test.flow_from_directory(
    test_flow_path,
    target_size = image_size,
    batch_size = batch_size,
    color_mode = 'rgb',
    classes = ['A','B', 'D', 'E', 'G'],
    class_mode = 'categorical',
    shuffle = True,
    seed = 42
)
# Out:
# Found 1000 images belonging to 5 classes.
# Found 500 images belonging to 5 classes.

# %%
from keras.models import Sequential
from keras.layers import Flatten,InputLayer,Dense, Dropout, Convolution2D, MaxPool2D, Dropout, BatchNormalization

# %%
def add_conv_layer(model,size,name='Layer Conv'):
    model.add(
        Convolution2D(
            size,
            (3,3),
            activation='relu',
            padding='same',
        )
    )
    model.add(
        Convolution2D(
            size,
            (3,3),
            activation='relu',
            padding='same'
        )
    )
    model.add(
        Convolution2D(
            size,
            (3,3),
            activation='relu',
            padding='same',
        )
    )
    model.add(
        Convolution2D(
            size,
            (3,3),
            activation='relu',
            padding='same',
        )
    )
    
    model.add(MaxPool2D())
    return model

# %%
model = Sequential(name='ConvolutionNetworkChars')
model.add(Convolution2D(16,(3,3),activation='relu',padding="same",input_shape=[32,32,3]))
model.add(Convolution2D(16,(3,3),activation='relu',padding="same"))
model.add(MaxPool2D())
add_conv_layer(model,32)
add_conv_layer(model,64)
add_conv_layer(model,128)
add_conv_layer(model,256)
model.add(Flatten())
model.add(Dense(256,activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(128,activation='relu'))

model.add(Dense(5,activation='softmax'))

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "ConvolutionNetworkChars"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 16)        448
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        2320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        4640
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 32)        9248
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 32)        9248
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 64)          18496
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 4, 4, 128)         73856
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 4, 4, 128)         147584
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 4, 4, 128)         147584
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 4, 4, 128)         147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 2, 2, 256)         295168
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 2, 2, 256)         590080
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 2, 2, 256)         590080
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 2, 2, 256)         590080
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               65792
# _________________________________________________________________
# batch_normalization (BatchNo (None, 256)               1024
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 2,846,805
# Trainable params: 2,846,293
# Non-trainable params: 512
# _________________________________________________________________

# %%
history = model.fit(train_images, epochs=50, validation_data = test_images)
# Out:
# /usr/local/lib/python3.8/site-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.8/site-packages/keras_preprocessing/image/image_data_generator.py:728: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# Epoch 1/50
# 32/32 [==============================] - 13s 415ms/step - loss: 1.3121 - accuracy: 0.3670 - val_loss: 1.7456 - val_accuracy: 0.2000
# Epoch 2/50
# 32/32 [==============================] - 12s 381ms/step - loss: 1.0668 - accuracy: 0.4380 - val_loss: 3.1610 - val_accuracy: 0.2140
# Epoch 3/50
# 32/32 [==============================] - 12s 387ms/step - loss: 1.0165 - accuracy: 0.4490 - val_loss: 68.5988 - val_accuracy: 0.2000
# Epoch 4/50
# 32/32 [==============================] - 11s 352ms/step - loss: 1.0116 - accuracy: 0.4950 - val_loss: 44.2935 - val_accuracy: 0.2000
# Epoch 5/50
# 32/32 [==============================] - 10s 316ms/step - loss: 0.8776 - accuracy: 0.5910 - val_loss: 58.4910 - val_accuracy: 0.2000
# Epoch 6/50
# 32/32 [==============================] - 10s 322ms/step - loss: 0.8862 - accuracy: 0.5540 - val_loss: 16.9026 - val_accuracy: 0.2200
# Epoch 7/50
# 32/32 [==============================] - 11s 358ms/step - loss: 0.7969 - accuracy: 0.6210 - val_loss: 6.5764 - val_accuracy: 0.3200
# Epoch 8/50
# 32/32 [==============================] - 11s 340ms/step - loss: 0.6765 - accuracy: 0.6960 - val_loss: 6.9164 - val_accuracy: 0.3060
# Epoch 9/50
# 32/32 [==============================] - 13s 402ms/step - loss: 0.6137 - accuracy: 0.7170 - val_loss: 11.9741 - val_accuracy: 0.2580
# Epoch 10/50
# 32/32 [==============================] - 12s 387ms/step - loss: 0.5853 - accuracy: 0.7340 - val_loss: 12.8836 - val_accuracy: 0.2760
# Epoch 11/50
# 32/32 [==============================] - 11s 331ms/step - loss: 0.5646 - accuracy: 0.7550 - val_loss: 7.8542 - val_accuracy: 0.3020
# Epoch 12/50
# 32/32 [==============================] - 10s 316ms/step - loss: 0.5495 - accuracy: 0.7600 - val_loss: 13.2223 - val_accuracy: 0.2920
# Epoch 13/50
# 32/32 [==============================] - 13s 421ms/step - loss: 0.9082 - accuracy: 0.6390 - val_loss: 29.5132 - val_accuracy: 0.2480
# Epoch 14/50
# 32/32 [==============================] - 11s 355ms/step - loss: 0.7960 - accuracy: 0.6490 - val_loss: 18.4691 - val_accuracy: 0.2120
# Epoch 15/50
# 32/32 [==============================] - 10s 313ms/step - loss: 0.5879 - accuracy: 0.7450 - val_loss: 3.8231 - val_accuracy: 0.3120
# Epoch 16/50
# 32/32 [==============================] - 12s 363ms/step - loss: 0.6434 - accuracy: 0.7200 - val_loss: 6.9056 - val_accuracy: 0.2880
# Epoch 17/50
# 32/32 [==============================] - 10s 324ms/step - loss: 0.6614 - accuracy: 0.7250 - val_loss: 10.6744 - val_accuracy: 0.2460
# Epoch 18/50
# 32/32 [==============================] - 11s 346ms/step - loss: 0.6715 - accuracy: 0.7000 - val_loss: 6.6045 - val_accuracy: 0.2920
# Epoch 19/50
# 32/32 [==============================] - 13s 417ms/step - loss: 0.5334 - accuracy: 0.7610 - val_loss: 6.9091 - val_accuracy: 0.2480
# Epoch 20/50
# 32/32 [==============================] - 13s 401ms/step - loss: 0.4797 - accuracy: 0.8010 - val_loss: 3.8533 - val_accuracy: 0.4280
# Epoch 21/50
# 32/32 [==============================] - 12s 369ms/step - loss: 0.5012 - accuracy: 0.7800 - val_loss: 12.6329 - val_accuracy: 0.2260
# Epoch 22/50
# 32/32 [==============================] - 11s 334ms/step - loss: 0.4227 - accuracy: 0.8310 - val_loss: 4.6138 - val_accuracy: 0.3580
# Epoch 23/50
# 32/32 [==============================] - 10s 322ms/step - loss: 0.4268 - accuracy: 0.8190 - val_loss: 3.3259 - val_accuracy: 0.4560
# Epoch 24/50
# 32/32 [==============================] - 9s 276ms/step - loss: 0.4432 - accuracy: 0.8210 - val_loss: 6.9004 - val_accuracy: 0.3060
# Epoch 25/50
# 32/32 [==============================] - 10s 310ms/step - loss: 0.4686 - accuracy: 0.8090 - val_loss: 4.5641 - val_accuracy: 0.3900
# Epoch 26/50
# 32/32 [==============================] - 9s 283ms/step - loss: 0.4525 - accuracy: 0.8180 - val_loss: 6.0219 - val_accuracy: 0.3080
# Epoch 27/50
# 32/32 [==============================] - 10s 307ms/step - loss: 0.5012 - accuracy: 0.8050 - val_loss: 10.9147 - val_accuracy: 0.3280
# Epoch 28/50
# 32/32 [==============================] - 10s 328ms/step - loss: 0.4684 - accuracy: 0.8020 - val_loss: 5.5967 - val_accuracy: 0.3460
# Epoch 29/50
# 32/32 [==============================] - 11s 348ms/step - loss: 0.3669 - accuracy: 0.8430 - val_loss: 2.9503 - val_accuracy: 0.4580
# Epoch 30/50
# 32/32 [==============================] - 12s 389ms/step - loss: 0.3543 - accuracy: 0.8580 - val_loss: 5.2056 - val_accuracy: 0.3860
# Epoch 31/50
# 32/32 [==============================] - 11s 345ms/step - loss: 0.5872 - accuracy: 0.7630 - val_loss: 5.9112 - val_accuracy: 0.3980
# Epoch 32/50
# 32/32 [==============================] - 14s 425ms/step - loss: 0.4066 - accuracy: 0.8320 - val_loss: 6.7351 - val_accuracy: 0.3040
# Epoch 33/50
# 32/32 [==============================] - 14s 432ms/step - loss: 0.4282 - accuracy: 0.8130 - val_loss: 4.8713 - val_accuracy: 0.3540
# Epoch 34/50
# 32/32 [==============================] - 11s 336ms/step - loss: 0.3550 - accuracy: 0.8660 - val_loss: 5.0047 - val_accuracy: 0.3500
# Epoch 35/50
# 32/32 [==============================] - 10s 327ms/step - loss: 0.3202 - accuracy: 0.8870 - val_loss: 3.5284 - val_accuracy: 0.4040
# Epoch 36/50
# 32/32 [==============================] - 12s 390ms/step - loss: 0.3279 - accuracy: 0.8840 - val_loss: 3.9813 - val_accuracy: 0.3860
# Epoch 37/50
# 32/32 [==============================] - 11s 334ms/step - loss: 0.4779 - accuracy: 0.7940 - val_loss: 10.1730 - val_accuracy: 0.3000
# Epoch 38/50
# 32/32 [==============================] - 10s 326ms/step - loss: 0.3912 - accuracy: 0.8780 - val_loss: 3.7668 - val_accuracy: 0.4580
# Epoch 39/50
# 32/32 [==============================] - 13s 393ms/step - loss: 0.3134 - accuracy: 0.8760 - val_loss: 2.7766 - val_accuracy: 0.5400
# Epoch 40/50
# 32/32 [==============================] - 11s 331ms/step - loss: 0.5543 - accuracy: 0.8000 - val_loss: 4.0212 - val_accuracy: 0.3600
# Epoch 41/50
# 32/32 [==============================] - 11s 337ms/step - loss: 0.3521 - accuracy: 0.8910 - val_loss: 3.4624 - val_accuracy: 0.4080
# Epoch 42/50
# 32/32 [==============================] - 11s 342ms/step - loss: 0.3192 - accuracy: 0.8770 - val_loss: 3.9721 - val_accuracy: 0.4640
# Epoch 43/50
# 32/32 [==============================] - 13s 413ms/step - loss: 0.2660 - accuracy: 0.9100 - val_loss: 3.6375 - val_accuracy: 0.5340
# Epoch 44/50
# 32/32 [==============================] - 14s 443ms/step - loss: 0.2428 - accuracy: 0.9120 - val_loss: 4.7663 - val_accuracy: 0.3360
# Epoch 45/50
# 32/32 [==============================] - 10s 302ms/step - loss: 0.3959 - accuracy: 0.8460 - val_loss: 3.7779 - val_accuracy: 0.4860
# Epoch 46/50
# 32/32 [==============================] - 9s 291ms/step - loss: 0.3317 - accuracy: 0.8640 - val_loss: 12.4448 - val_accuracy: 0.2800
# Epoch 47/50
# 32/32 [==============================] - 9s 288ms/step - loss: 0.3424 - accuracy: 0.8540 - val_loss: 5.0896 - val_accuracy: 0.3580
# Epoch 48/50
# 32/32 [==============================] - 13s 410ms/step - loss: 0.3724 - accuracy: 0.8460 - val_loss: 8.1948 - val_accuracy: 0.3280
# Epoch 49/50
# 32/32 [==============================] - 13s 395ms/step - loss: 0.2400 - accuracy: 0.9040 - val_loss: 35.6483 - val_accuracy: 0.5580
# Epoch 50/50
# 32/32 [==============================] - 13s 413ms/step - loss: 0.2617 - accuracy: 0.8970 - val_loss: 11.3181 - val_accuracy: 0.2860

# %%
scores = model.evaluate(test_images)
print(f'* Loss = {scores[0]}\n* Accuracy = {scores[1]}')
# Out:
# 16/16 [==============================] - 1s 35ms/step - loss: 11.3181 - accuracy: 0.2860
# * Loss = 11.318081855773926
# * Accuracy = 0.28600001335144043

# %%
from keras.utils.vis_utils import plot_model

# %%
plot_model(model, to_file='./Conv_model.png', show_shapes=True, show_layer_names=True)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('./Conv_accuracy.png')
plt.show()
#
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('./Conv_loss.png')
plt.show()
